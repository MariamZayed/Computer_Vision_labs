# %% [markdown]
# <a href="https://colab.research.google.com/github/MariamZayed/Computer_Vision_labs/blob/main/Lab6_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Importing Section

# %%
from google.colab.patches import cv2_imshow as cv_imshow

# %%
pip install opencv-contrib-python

# %%
pip install opencv-python

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt #not used

# %%
img = cv.imread('doll.jpg')
img = cv.resize(img,(0,0),fx=0.25, fy=0.25)
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=437x620 at 0x7F5305BFF590>

# %% [markdown]
# ##Feature Dedection using Fast
# * we should know that keypoints = Interest points
# -- interest points or keypoints are the edge or corner or any rapid change in the intensity value of the pixel.
# *  اي زنقه في السنتاكس الفاست والسيفت بنحط نون

# %%
#creating an object from fast class with it's default values
fast = cv.FastFeatureDetector_create()
#extract and detect all the keypoints in the image
extracted_Keypoints = fast.detect(img, None)
#finially, draw this keypoints an the original image
img2 = cv.drawKeypoints(img, extracted_Keypoints, None, color= (255,0,0))
#extracting all default values that comes with fast object and with nonmaxsuppression is ture
print("threshold: {}".format(fast.getThreshold()) )
print("nonMaxSuppression: {}".format(fast.getNonmaxSuppression()) )
print("neighbours: {}".format(fast.getType()) )
print("keypoints with nonmaxSuppressin: {}".format(len(extracted_Keypoints)) )
cv_imshow(img2)

#disable for non-maxSuppression 
fast.setNonmaxSuppression(0)
extracted_Keypoints = fast.detect(img, None)
img3 = cv.drawKeypoints(img, extracted_Keypoints, None, color=(255,0,0))
cv_imshow(img3)
# Out:
# threshold: 10
# nonMaxSuppression: True
# neighbours: 2
# keypoints with nonmaxSuppressin: 1039
# <PIL.Image.Image image mode=RGB size=437x620 at 0x7F5305C70BD0>
# <PIL.Image.Image image mode=RGB size=437x620 at 0x7F5305C70590>

# %% [markdown]
# cv.drawKeypoints(img, extracted_Keypoints, None, color= (255,0,0))
# * third param set it to None.
# * when is non-max-suppression is True, the interest points or keypoints (edges, corner) will be thin. True is the default value.
# *
# However, when it's set to false, keypoints will be thinner (lec 6)

# %% [markdown]
# ## SIFT

# %%
#create an object from SIFT class
sift = cv.SIFT_create()
#extract or detect kp form orginal image by sift dtection algorithm 
extracted_kp = sift.detect(img, None)
sift_img = cv.drawKeypoints(img, extracted_kp, None, color=(0,0,255))
cv_imshow(sift_img)

# you can actually compute keypoint and descriptors both in one line by next line of code!
extracted_kp, dest = sift.detectedAndCompute(img,None)
print(extracted_Keypoints)
print(dest)

# %% [markdown]
# Anyway, SIFT_create() is proabably not working, a non-free thing or whatever
